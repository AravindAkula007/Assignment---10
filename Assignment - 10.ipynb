# %%
pip install apyori
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=c7dbc192fad359630190aabb151d6218a8790e84949d66340a97a0be343d2d1e
#   Stored in directory: c:\users\marav\appdata\local\pip\cache\wheels\77\3d\a6\d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script apyori-run.exe is installed in 'C:\Users\marav\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# Import necessary libraries
import pandas as pd

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Data Preprocessing
# Load the dataset
df = pd.read_excel("G:\ExcelR\Data Science Assignments\Assignment 10\Association Rules\\Online retail.xlsx",header = None)
df

# Handle missing values
df.dropna(inplace=True)
# Remove duplicates if any
df.drop_duplicates(inplace=True)
# Out:
# <>:9: DeprecationWarning: invalid escape sequence '\E'
# <>:9: DeprecationWarning: invalid escape sequence '\E'
# C:\Users\marav\AppData\Local\Temp\ipykernel_672\814954298.py:9: DeprecationWarning: invalid escape sequence '\E'
#   df = pd.read_excel("G:\ExcelR\Data Science Assignments\Assignment 10\Association Rules\\Online retail.xlsx",header = None)

# %%
#creating the list to get all those dataset values and storing in trans
trans = []
for i in range(0, 7501):
  trans.append([str(df.values[i,j]) for j in range(0, 1)])
trans
# Out:
# [['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil'],
#  ['burgers,meatballs,eggs'],
#  ['chutney'],
#  ['turkey,avocado'],
#  ['mineral water,milk,energy bar,whole wheat rice,green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta,french fries'],
#  ['soup,light cream,shallot'],
#  ['frozen vegetables,spaghetti,green tea'],
#  ['french fries'],
#  ['eggs,pet food'],
#  ['cookies'],
#  ['turkey,burgers,mineral water,eggs,cooking oil'],
#  ['spaghetti,champagne,cookies'],
#  ['mineral water,salmon'],
#  ['mineral water'],
#  ['shrimp,chocolate,chicken,honey,oil,cooking oil,low fat yogurt'],
#  ['turkey,eggs'],
#  ['turkey,fresh tuna,tomatoes,spaghetti,mineral water,black tea,salmon,eggs,chicken,extra dark chocolate'],
#  ['meatballs,milk,honey,french fries,protein bar'],
# ...

# %%
from apyori import apriori
rules = apriori(transactions = trans,
                min_support = 0.005, 
                min_confidence = 0.2, 
                min_lift = 3, 
                min_length = 2, 
                max_length = 2)

# %%
rules = apriori(transactions = trans, 
                min_support = 0.00001, 
                min_confidence = 0.0001, 
                min_lift = 1, 
                min_length = 2, 
                max_length = 5)

# %%
rules
# Out:
# <generator object apriori at 0x000001DDE47FF320>

# %%
results = list(rules)
len(results)
# Out:
# 5176

# %%
results[0]
# Out:
# RelationRecord(items=frozenset({'almonds'}), support=0.0002666311158512198, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'almonds'}), confidence=0.0002666311158512198, lift=1.0)])

# %%
#Getting all the different combination of items
print("Support",results[0][1])
print("Base item",results[0][2][0][0])
print("add item",results[0][2][0][1])
print("confidence",results[0][2][0][2])
print("lift",results[0][2][0][3])
# Out:
# Support 0.0002666311158512198
# Base item frozenset()
# add item frozenset({'almonds'})
# confidence 0.0002666311158512198
# lift 1.0

# %%
#creating list and appending values using for loop
a=[]
b=[]
c=[]
d=[]
e=[]


for i in range(0,9):
    a.append(results[i][2][0][0])
    b.append(results[i][2][0][1])
    c.append(results[i][1])
    d.append(results[i][2][0][2])
    e.append(results[i][2][0][3])

# %%
a = pd.DataFrame(a)
b = pd.DataFrame(b)
c = pd.DataFrame(c)
d = pd.DataFrame(d)
e = pd.DataFrame(e)
df_new = pd.concat([a,b,c,d,e],axis=1)

# %%
df_new.columns = ["Base item",'Add item','support','confidence']
df_new
# Out:
#                                            Base item  Add item   support  \
# 0                                            almonds  0.000267  0.000267
# 1                        almonds,cake,low fat yogurt  0.000133  0.000133
# 2                                    almonds,cookies  0.000133  0.000133
# 3                                       almonds,eggs  0.000133  0.000133
# 4                               almonds,eggs,cookies  0.000133  0.000133
# 5    almonds,eggs,cooking oil,french fries,green tea  0.000133  0.000133
# 6                           almonds,eggs,yogurt cake  0.000133  0.000133
# 7                                almonds,french wine  0.000133  0.000133
# 8  almonds,french wine,green tea,french fries,esc...  0.000133  0.000133
#
#    confidence
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
# 5         1.0
# 6         1.0
# 7         1.0
# 8         1.0
